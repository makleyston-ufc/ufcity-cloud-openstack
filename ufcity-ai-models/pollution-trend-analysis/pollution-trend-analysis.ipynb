# %% [markdown]
# # Pollution trend analysis
#
# This document uses the [US Air Pollution](https://www.kaggle.com/datasets/mexwell/us-air-pollution).
# The goal this analysis is to note the trend of pollution using a trend analysis machine learning model like ARIMA, SARIMA, and ETS.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../datasets/pollution-trend-analysis/uspollution_pollution_us_2000_2016.csv')

# %%
df.shape
# Out:
# (1746661, 29)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State Code', 'County Code', 'Site Num', 'Address',
#        'State', 'County', 'City', 'Date Local', 'NO2 Units', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 'O3 Units',
#        'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'SO2 Units',
#        'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
#        'CO Units', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI'],
#       dtype='object')

# %%
df.groupby('City').size().sort_values(ascending=False)
# Out:
# City
# Not in a city         138411
# New York               46887
# Los Angeles            42241
# Phoenix                37912
# El Paso                36908
#                        ...
# St. Ann                  860
# Kenner                   544
# Bakersfield              434
# Dentsville (Dents)       116
# Roosevelt                104
# Length: 144, dtype: int64

# %%
df_ny = df[df['City'] == 'New York'].reset_index(drop=True)

df_ny['Date Local'] = pd.to_datetime(df_ny['Date Local'])
df_ny = df_ny.groupby('Date Local').mean().reset_index()
df_ny.set_index('Date Local', inplace=True)

last_two_years = df_ny.index.max() - pd.DateOffset(years=2)
df_ny = df_ny[last_two_years:df_ny.index.max()]

df_bkp = df_ny.copy()

# %%
def plot(_df, _column):
    plt.figure(figsize=(5, 3))
    plt.plot(_df.index, _df[_column], label=_column)
    plt.xlabel('Data')
    plt.ylabel(f'Concentração de {_column}')
    plt.title(f'Tendência de {_column} Mean ao longo do tempo')
    plt.legend()
    plt.show()

# %%
cols = ['NO2 Mean', 'O3 Mean', 'SO2 Mean', 'CO Mean']
for c in cols:
    plot(df_ny, c)

# %%
df_ny.dtypes
# Out:
# Unnamed: 0           float64
# State Code           float64
# County Code          float64
# Site Num             float64
# NO2 Mean             float64
# NO2 1st Max Value    float64
# NO2 1st Max Hour     float64
# NO2 AQI              float64
# O3 Mean              float64
# O3 1st Max Value     float64
# O3 1st Max Hour      float64
# O3 AQI               float64
# SO2 Mean             float64
# SO2 1st Max Value    float64
# SO2 1st Max Hour     float64
# SO2 AQI              float64
# CO Mean              float64
# CO 1st Max Value     float64
# CO 1st Max Hour      float64
# CO AQI               float64
# dtype: object

# %%
correlation_matrix = df_ny[['CO Mean', 'SO2 Mean', 'NO2 Mean', 'O3 Mean']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='RdYlBu')
plt.title('Correlation')
plt.show()

# %%
arima_models_dict = {}
sarima_models_dict = {}
ets_models_dict = {}

# %% [markdown]
# ### ARIMA

# %%
from pmdarima.arima import auto_arima

df_ny_arima = df_ny.copy()

# Split the data into training (80%) and testing (20%)
train_size = int(len(df_ny_arima) * 0.8)
train, test = df_ny_arima[:train_size], df_ny_arima[train_size:]

for col in cols:
    # Find the best parameters using AutoARIMA
    model = auto_arima(train[col], seasonal=False, trace=True)
    # Fit the model to the training data
    model_fit = model.fit(train[col])
    arima_models_dict[col] = model_fit
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3779.759, Time=0.49 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3990.478, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3964.844, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3860.202, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3988.488, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3777.968, Time=0.21 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3776.325, Time=0.16 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=3777.935, Time=0.21 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3795.585, Time=0.24 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=3778.010, Time=0.91 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3774.523, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3858.309, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3776.162, Time=0.12 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=3776.128, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3793.785, Time=0.08 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=3776.159, Time=0.46 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 3.354 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-4170.026, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-4003.436, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-4036.660, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-4117.912, Time=0.62 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-4005.418, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-4183.684, Time=0.57 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-4175.377, Time=0.38 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-4139.467, Time=0.33 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-4189.130, Time=0.70 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-4186.424, Time=0.55 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-4186.255, Time=0.82 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-4182.964, Time=1.10 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-4184.928, Time=0.68 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-4181.927, Time=0.97 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-4190.363, Time=0.53 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=-4184.491, Time=0.18 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-4191.131, Time=0.69 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-4177.110, Time=0.13 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-4182.659, Time=0.39 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-4186.961, Time=1.05 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-4119.587, Time=0.25 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-4188.435, Time=0.39 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-4176.320, Time=0.14 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 11.149 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=943.970, Time=1.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1078.820, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1053.178, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1000.574, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1076.830, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=925.617, Time=0.45 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=925.430, Time=0.23 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=925.475, Time=0.33 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=931.252, Time=0.26 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=927.470, Time=0.65 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=923.452, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=998.583, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=923.643, Time=0.19 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=923.500, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=929.281, Time=0.11 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=925.495, Time=0.28 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 4.208 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-1127.885, Time=0.75 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-980.055, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-992.494, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1033.515, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-982.040, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-1149.268, Time=0.79 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-1148.119, Time=0.72 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-1134.770, Time=0.69 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-1147.636, Time=0.87 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-1149.570, Time=1.09 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-1147.251, Time=0.69 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-1145.669, Time=1.28 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=-1151.469, Time=0.30 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-1150.026, Time=0.22 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-1149.536, Time=0.40 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=-1149.499, Time=0.31 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-1151.267, Time=0.30 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=-1147.760, Time=0.82 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[0]
# Total fit time: 9.819 seconds

# %%
arima_models_dict
# Out:
# {'NO2 Mean': ARIMA(order=(0, 1, 2), scoring_args={}, suppress_warnings=True,
#        with_intercept=False),
#  'O3 Mean': ARIMA(order=(1, 1, 2), scoring_args={}, suppress_warnings=True,
#        with_intercept=False),
#  'SO2 Mean': ARIMA(order=(0, 1, 2), scoring_args={}, suppress_warnings=True,
#        with_intercept=False),
#  'CO Mean': ARIMA(order=(0, 1, 3), scoring_args={}, suppress_warnings=True,
#        with_intercept=False)}

# %%
# Plot the results
for key, model in arima_models_dict.items():
    # Make predictions for the test period
    forecast = model.predict(n_periods=len(test))
    # Plot the results
    plt.figure(figsize=(10, 6))
    plt.plot(train.index, train[key], label='Training')
    plt.plot(test.index, test[key], label='Testing')
    plt.plot(test.index, forecast, label='Predictions')
    plt.xlabel('Date')
    plt.ylabel('{key} Concentration')
    plt.title(f'Trend Forecast with AutoARIMA {forecast.iloc[0]} - {forecast.iloc[len(forecast)-1]}')
    plt.legend()
    plt.show()

# %% [markdown]
# ### SARIMA

# %%
df_ny_sarima = df_ny.copy()

import pmdarima as pm
from pmdarima.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

train, test = train_test_split(df_ny_sarima, train_size=0.8)

for col in cols:
    # Find the best SARIMA parameters using auto_arima
    model = pm.auto_arima(train[col], seasonal=True, m=12, trace=True, error_action='ignore', suppress_warnings=True)
    # Fit the SARIMA model to the training data with the best parameters
    model.fit(train[col])
    sarima_models_dict[col] = model
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=3779.434, Time=1.86 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=3990.478, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=3966.648, Time=0.23 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=3862.118, Time=0.41 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=3988.488, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=3781.721, Time=1.01 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=3781.716, Time=1.00 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=3780.262, Time=3.45 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=3780.287, Time=3.43 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=3779.759, Time=0.39 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=3781.554, Time=1.84 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=3781.248, Time=1.84 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=3782.271, Time=4.91 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=3777.589, Time=1.29 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=3779.929, Time=0.44 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=3779.924, Time=0.91 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=3778.407, Time=2.41 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=3778.433, Time=2.87 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=3777.968, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=3779.734, Time=1.40 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=3779.417, Time=1.20 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=3780.311, Time=3.84 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.96 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=3799.585, Time=0.59 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=2.11 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=3862.415, Time=0.86 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=3777.555, Time=1.48 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=3779.896, Time=0.59 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=3779.890, Time=0.41 sec
#  ARIMA(0,1,3)(2,0,1)[12] intercept   : AIC=3778.373, Time=1.96 sec
#  ARIMA(0,1,3)(1,0,2)[12] intercept   : AIC=3778.398, Time=2.23 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=3777.935, Time=0.21 sec
#  ARIMA(0,1,3)(0,0,2)[12] intercept   : AIC=3779.703, Time=1.10 sec
#  ARIMA(0,1,3)(2,0,0)[12] intercept   : AIC=3779.388, Time=0.89 sec
#  ARIMA(0,1,3)(2,0,2)[12] intercept   : AIC=3780.280, Time=3.81 sec
#  ARIMA(0,1,4)(1,0,1)[12] intercept   : AIC=3779.359, Time=1.78 sec
#  ARIMA(1,1,4)(1,0,1)[12] intercept   : AIC=3781.313, Time=2.45 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=3775.739, Time=0.77 sec
#  ARIMA(0,1,3)(0,0,1)[12]             : AIC=3778.088, Time=0.25 sec
#  ARIMA(0,1,3)(1,0,0)[12]             : AIC=3778.082, Time=0.19 sec
#  ARIMA(0,1,3)(2,0,1)[12]             : AIC=3776.557, Time=1.21 sec
#  ARIMA(0,1,3)(1,0,2)[12]             : AIC=3776.582, Time=1.43 sec
#  ARIMA(0,1,3)(0,0,0)[12]             : AIC=3776.128, Time=0.13 sec
#  ARIMA(0,1,3)(0,0,2)[12]             : AIC=3777.882, Time=0.62 sec
#  ARIMA(0,1,3)(2,0,0)[12]             : AIC=3777.564, Time=0.45 sec
#  ARIMA(0,1,3)(2,0,2)[12]             : AIC=3778.459, Time=2.39 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=inf, Time=0.58 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=3775.562, Time=1.90 sec
#  ARIMA(1,1,3)(0,0,1)[12]             : AIC=3778.016, Time=1.00 sec
#  ARIMA(1,1,3)(1,0,0)[12]             : AIC=3777.999, Time=0.95 sec
#  ARIMA(1,1,3)(2,0,1)[12]             : AIC=3776.955, Time=2.92 sec
#  ARIMA(1,1,3)(1,0,2)[12]             : AIC=3776.856, Time=3.35 sec
#  ARIMA(1,1,3)(0,0,0)[12]             : AIC=3776.159, Time=0.49 sec
#  ARIMA(1,1,3)(0,0,2)[12]             : AIC=3778.372, Time=2.07 sec
#  ARIMA(1,1,3)(2,0,0)[12]             : AIC=3778.081, Time=1.68 sec
#  ARIMA(1,1,3)(2,0,2)[12]             : AIC=3780.424, Time=3.91 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=3775.774, Time=0.84 sec
#  ARIMA(2,1,3)(1,0,1)[12]             : AIC=inf, Time=1.84 sec
#  ARIMA(1,1,4)(1,0,1)[12]             : AIC=3779.494, Time=1.87 sec
#  ARIMA(0,1,4)(1,0,1)[12]             : AIC=3777.540, Time=0.98 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=3777.617, Time=1.00 sec
#  ARIMA(2,1,4)(1,0,1)[12]             : AIC=3776.924, Time=1.67 sec
#
# Best model:  ARIMA(1,1,3)(1,0,1)[12]
# Total fit time: 90.986 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=-4178.469, Time=1.13 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-4003.436, Time=0.12 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-4042.778, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-4085.369, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-4005.418, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=-4185.353, Time=1.54 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=-4170.026, Time=0.49 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=-4179.520, Time=2.17 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=-4188.142, Time=2.06 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=-4179.221, Time=2.31 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=-4180.850, Time=3.79 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=-4186.443, Time=2.10 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=-4132.737, Time=0.50 sec
#  ARIMA(3,1,2)(1,0,0)[12] intercept   : AIC=-4062.887, Time=2.63 sec
#  ARIMA(2,1,3)(1,0,0)[12] intercept   : AIC=-4187.513, Time=1.79 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=-4144.443, Time=0.45 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=-4191.894, Time=1.62 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=-4189.130, Time=0.78 sec
#  ARIMA(1,1,3)(2,0,0)[12] intercept   : AIC=-4190.881, Time=3.17 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=-4190.409, Time=2.32 sec
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=-4186.640, Time=1.24 sec
#  ARIMA(1,1,3)(2,0,1)[12] intercept   : AIC=-4185.460, Time=3.94 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=-4186.254, Time=1.22 sec
#  ARIMA(1,1,4)(1,0,0)[12] intercept   : AIC=-4185.814, Time=0.86 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=-4178.731, Time=0.78 sec
#  ARIMA(0,1,4)(1,0,0)[12] intercept   : AIC=-4187.787, Time=0.61 sec
#  ARIMA(2,1,4)(1,0,0)[12] intercept   : AIC=-4183.579, Time=0.87 sec
#  ARIMA(1,1,3)(1,0,0)[12]             : AIC=-4193.071, Time=0.58 sec
#  ARIMA(1,1,3)(0,0,0)[12]             : AIC=-4190.363, Time=0.39 sec
#  ARIMA(1,1,3)(2,0,0)[12]             : AIC=-4192.214, Time=1.15 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=-4191.616, Time=1.34 sec
#  ARIMA(1,1,3)(0,0,1)[12]             : AIC=-4192.847, Time=0.68 sec
#  ARIMA(1,1,3)(2,0,1)[12]             : AIC=-4190.036, Time=2.38 sec
#  ARIMA(0,1,3)(1,0,0)[12]             : AIC=-4193.694, Time=0.57 sec
#  ARIMA(0,1,3)(0,0,0)[12]             : AIC=-4184.491, Time=0.12 sec
#  ARIMA(0,1,3)(2,0,0)[12]             : AIC=-4192.746, Time=1.19 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=-4192.018, Time=0.94 sec
#  ARIMA(0,1,3)(0,0,1)[12]             : AIC=-4187.310, Time=0.30 sec
#  ARIMA(0,1,3)(2,0,1)[12]             : AIC=-4190.570, Time=1.72 sec
#  ARIMA(0,1,2)(1,0,0)[12]             : AIC=-4195.642, Time=0.65 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=-4177.110, Time=0.08 sec
#  ARIMA(0,1,2)(2,0,0)[12]             : AIC=-4178.860, Time=0.42 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=-4178.523, Time=0.42 sec
#  ARIMA(0,1,2)(0,0,1)[12]             : AIC=-4179.985, Time=0.61 sec
#  ARIMA(0,1,2)(2,0,1)[12]             : AIC=-4176.608, Time=1.30 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=-4128.248, Time=0.46 sec
#  ARIMA(1,1,2)(1,0,0)[12]             : AIC=-4173.519, Time=0.14 sec
#  ARIMA(1,1,1)(1,0,0)[12]             : AIC=-4186.675, Time=0.83 sec
#
# Best model:  ARIMA(0,1,2)(1,0,0)[12]
# Total fit time: 55.410 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=930.609, Time=2.38 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1078.820, Time=0.09 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1053.695, Time=0.26 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1002.263, Time=0.60 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1076.830, Time=0.13 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=1001.476, Time=1.83 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=929.659, Time=1.74 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=943.970, Time=1.06 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=929.425, Time=3.95 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=1006.965, Time=3.96 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=929.029, Time=1.76 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=927.310, Time=0.91 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=925.617, Time=0.52 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=927.297, Time=0.66 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=929.263, Time=1.21 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=925.430, Time=0.23 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=927.092, Time=0.47 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=927.079, Time=0.40 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=929.046, Time=1.08 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1000.574, Time=0.12 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=925.475, Time=0.34 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=931.252, Time=0.27 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=927.470, Time=0.58 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=923.452, Time=0.07 sec
#  ARIMA(0,1,2)(1,0,0)[12]             : AIC=925.115, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,1)[12]             : AIC=925.101, Time=0.15 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=927.068, Time=0.52 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=998.583, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=923.643, Time=0.14 sec
#  ARIMA(0,1,3)(0,0,0)[12]             : AIC=923.500, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=929.281, Time=0.10 sec
#  ARIMA(1,1,3)(0,0,0)[12]             : AIC=925.495, Time=0.24 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[12]
# Total fit time: 26.131 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=-1124.167, Time=1.04 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-980.055, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-990.508, Time=0.29 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-1031.661, Time=0.74 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-982.040, Time=0.10 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=-1126.237, Time=0.63 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=-1127.885, Time=0.63 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=-1125.648, Time=0.65 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=-1149.268, Time=0.64 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=-1147.291, Time=1.35 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=-1147.302, Time=1.46 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=-1145.340, Time=1.68 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=-1148.119, Time=0.46 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-1134.770, Time=0.58 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=-1147.636, Time=0.71 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-1033.515, Time=0.15 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=-1149.570, Time=0.82 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=-1147.627, Time=1.17 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=-1147.625, Time=1.59 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=-1145.683, Time=1.87 sec
#  ARIMA(0,1,4)(0,0,0)[12] intercept   : AIC=-1147.251, Time=0.63 sec
#  ARIMA(1,1,4)(0,0,0)[12] intercept   : AIC=-1145.669, Time=0.98 sec
#  ARIMA(0,1,3)(0,0,0)[12]             : AIC=-1151.469, Time=0.22 sec
#  ARIMA(0,1,3)(1,0,0)[12]             : AIC=-1149.534, Time=0.49 sec
#  ARIMA(0,1,3)(0,0,1)[12]             : AIC=-1149.527, Time=0.56 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=-1148.067, Time=0.99 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=-1150.026, Time=0.15 sec
#  ARIMA(1,1,3)(0,0,0)[12]             : AIC=-1149.536, Time=0.24 sec
#  ARIMA(0,1,4)(0,0,0)[12]             : AIC=-1149.499, Time=0.29 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=-1151.267, Time=0.27 sec
#  ARIMA(1,1,4)(0,0,0)[12]             : AIC=-1147.760, Time=0.73 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[12]
# Total fit time: 22.217 seconds

# %%
for key, model in sarima_models_dict.items():
    # Make predictions with the fitted model
    forecast = model.predict(len(test))
    # Calculate the Root Mean Squared Error (RMSE) of the predictions
    rmse = np.sqrt(mean_squared_error(test[key], forecast))
    print(f'RMSE: {rmse}')
    print(f'{forecast.iloc[0]} - {forecast.iloc[len(forecast)-1]}')
    plt.figure(figsize=(10, 6))
    plt.plot(train.index, train[key], label='Training')
    plt.plot(test.index, test[key], label='Testing')
    plt.plot(test.index, forecast, label='Predictions')
    plt.xlabel('Date')
    plt.ylabel(f'{key} Concentration')
    plt.title('Trend Forecast with AutoARIMA')
    plt.legend()
    plt.show()
# Out:
# RMSE: 8.816847128227408
# 22.761140156915346 - 18.782511126893397
# RMSE: 0.012275156886457727
# 0.011398406961441357 - 0.014054333511977121
# RMSE: 0.7268089245952535
# 1.2872367610584186 - 1.042687784810991
# RMSE: 0.1169862581168142
# 0.4150769103658451 - 0.3021620941868501

# %% [markdown]
# ### ETS

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

df_ny_ets = df_ny.copy()

df_ny_ets = df_ny_ets.asfreq('D')

for col in cols:
    # Fit the ETS model to the data
    model = ExponentialSmoothing(df_ny_ets[col], seasonal='add', trend='add', seasonal_periods=12)
    result = model.fit()
    ets_models_dict[col] = result

# %%
ets_models_dict
# Out:
# {'NO2 Mean': <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper at 0x7fd9552998e0>,
#  'O3 Mean': <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper at 0x7fd94f6ede80>,
#  'SO2 Mean': <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper at 0x7fd94f341070>,
#  'CO Mean': <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper at 0x7fd94f341250>}

# %%
for key, model in ets_models_dict.items():
    # Make predictions with the fitted model
    forecast = model.forecast(steps=12)
    # Plot the original data and the forecasts
    print(f'{forecast.iloc[0]} - {forecast.iloc[len(forecast)-1]}')
    plt.figure(figsize=(10, 6))
    plt.plot(df_ny_ets.index, df_ny_ets[key], label='Original Data')
    plt.plot(forecast.index, forecast, label='Forecast')
    plt.xlabel('Date')
    plt.ylabel(key)
    plt.title('Exponential Smoothing State Space Model (ETS) for NO2 Mean')
    plt.legend()
    plt.show()
# Out:
# 14.82212559549436 - 13.6197844853201
# 0.03285958403348098 - 0.035379198021815036
# 0.5225668065620693 - 0.44384586196164544
# 0.2581535506805742 - 0.24240969520517908

# %%
import joblib

for model_name, model in arima_models_dict.items():
    joblib.dump(model, f'{model_name}-ARIMA-pollution-trend-analysis-model.joblib')

for model_name, model in sarima_models_dict.items():
    joblib.dump(model, f'{model_name}-SARIMA-pollution-trend-analysis-model.joblib')
    
for model_name, model in ets_models_dict.items():
    joblib.dump(model, f'{model_name}-ETS-pollution-trend-analysis-model.joblib')

# %%
print(joblib.__version__)
# Out:
# 1.2.0

# %%
import json

results_dict = {}

for key, model in ets_models_dict.items():
    forecast = model.forecast(steps=24)
    results_dict[key] = forecast.tolist()

result_json = json.dumps(results_dict)

print(result_json)
# Out:
# {"NO2 Mean": [14.82212559549436, 14.311754960918147, 14.739735715741967, 12.720941904630715, 11.65929374852305, 13.16741138705186, 12.462819433695223, 11.868107840710096, 13.691995796081336, 13.840983687850041, 12.698022985182192, 13.6197844853201, 14.810852908333523, 14.30048227375731, 14.72846302858113, 12.70966921746988, 11.648021061362215, 13.156138699891025, 12.451546746534387, 11.856835153549259, 13.6807231089205, 13.829711000689205, 12.686750298021355, 13.608511798159265], "O3 Mean": [0.03285958403348098, 0.0327011960389166, 0.032026427982482876, 0.033609796963458644, 0.03282432771775832, 0.03333248944032671, 0.034006883509279565, 0.03490474103116435, 0.03306473108219696, 0.03292906761098306, 0.03486023520529261, 0.035379198021815036, 0.032934495599189866, 0.03277610760462549, 0.03210133954819176, 0.03368470852916753, 0.032899239283467205, 0.0334074010060356, 0.03408179507498845, 0.03497965259687324, 0.033139642647905844, 0.03300397917669195, 0.0349351467710015, 0.03545410958752392], "SO2 Mean": [0.5225668065620693, 0.5451123999296097, 0.4455436181910822, 0.38591051969463613, 0.3098727937542902, 0.3644379685944613, 0.35182595542410683, 0.35068726635818637, 0.3582118451043932, 0.3855338056413922, 0.40378554036990816, 0.44384586196164544, 0.5191608474475842, 0.5417064408151245, 0.442137659076597, 0.3825045605801509, 0.30646683463980506, 0.3610320094799761, 0.34841999630962167, 0.3472813072437011, 0.35480588598990803, 0.382127846526907, 0.400379581255423, 0.4404399028471602], "CO Mean": [0.2581535506805742, 0.2530643893131187, 0.26707892664877525, 0.2324037597155574, 0.22401234764376105, 0.23005166573241692, 0.22509723209292737, 0.21587953435043583, 0.23764898662337883, 0.24564533248322162, 0.23484815073334675, 0.24240969520517908, 0.2582200449712872, 0.2531308836038316, 0.2671454209394882, 0.2324702540062704, 0.22407884193447403, 0.23011816002312988, 0.22516372638364032, 0.2159460286411488, 0.23771548091409178, 0.24571182677393458, 0.2349146450240597, 0.24247618949589203]}

# %%
df
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 0                 0           4           13      3002
# 1                 1           4           13      3002
# 2                 2           4           13      3002
# 3                 3           4           13      3002
# 4                 4           4           13      3002
# ...             ...         ...          ...       ...
# 1746656       24599          56           21       100
# 1746657       24600          56           21       100
# 1746658       24601          56           21       100
# 1746659       24602          56           21       100
# 1746660       24603          56           21       100
#
#                                          Address    State    County  \
# 0        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 1        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 2        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 3        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 4        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# ...                                          ...      ...       ...
# 1746656    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
# 1746657    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
# 1746658    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
# 1746659    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
# 1746660    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
#
#                   City  Date Local          NO2 Units  ...          SO2 Units  \
# 0              Phoenix  2000-01-01  Parts per billion  ...  Parts per billion
# 1              Phoenix  2000-01-01  Parts per billion  ...  Parts per billion
# 2              Phoenix  2000-01-01  Parts per billion  ...  Parts per billion
# 3              Phoenix  2000-01-01  Parts per billion  ...  Parts per billion
# 4              Phoenix  2000-01-02  Parts per billion  ...  Parts per billion
# ...                ...         ...                ...  ...                ...
# 1746656  Not in a city  2016-03-30  Parts per billion  ...  Parts per billion
# 1746657  Not in a city  2016-03-31  Parts per billion  ...  Parts per billion
# 1746658  Not in a city  2016-03-31  Parts per billion  ...  Parts per billion
# 1746659  Not in a city  2016-03-31  Parts per billion  ...  Parts per billion
# 1746660  Not in a city  2016-03-31  Parts per billion  ...  Parts per billion
#
#          SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour SO2 AQI  \
# 0        3.000000                9.0                21    13.0
# 1        3.000000                9.0                21    13.0
# 2        2.975000                6.6                23     NaN
# 3        2.975000                6.6                23     NaN
# 4        1.958333                3.0                22     4.0
# ...           ...                ...               ...     ...
# 1746656  0.000000                0.0                 2     NaN
# 1746657 -0.022727                0.0                 0     0.0
# 1746658 -0.022727                0.0                 0     0.0
# 1746659  0.000000                0.0                 5     NaN
# 1746660  0.000000                0.0                 5     NaN
#
#                   CO Units   CO Mean  CO 1st Max Value  CO 1st Max Hour CO AQI
# 0        Parts per million  1.145833             4.200               21    NaN
# 1        Parts per million  0.878947             2.200               23   25.0
# 2        Parts per million  1.145833             4.200               21    NaN
# 3        Parts per million  0.878947             2.200               23   25.0
# 4        Parts per million  0.850000             1.600               23    NaN
# ...                    ...       ...               ...              ...    ...
# 1746656  Parts per million  0.091667             0.100                2    1.0
# 1746657  Parts per million  0.067714             0.127                0    NaN
# 1746658  Parts per million  0.100000             0.100                0    1.0
# 1746659  Parts per million  0.067714             0.127                0    NaN
# 1746660  Parts per million  0.100000             0.100                0    1.0
#
# [1746661 rows x 29 columns]
